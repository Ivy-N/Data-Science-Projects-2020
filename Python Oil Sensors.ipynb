# %%
import random # import random library
import string # import string library
from datetime import datetime #import datetime 

Dict={} 
ZL=[] # initiate list  ZL which takes in up to 16 random floats z 
L=len(ZL) # find length of ZL
WL=[] #initiate dictionary WL which takes in sets of floats W
 
def one_cluster(): #function that creates a set of 16 random floats
    X = range (0,16) # sets random floats to range from the first to 16th
    for x in X: #creates a for loop which dictates what will happen to each entry within the 16
        z = random.uniform(0,1) # creates a random float
        y=ZL.append(z) #appending random float to list ZL
        
 
while L<=(512-16): # dictates what will happen while the length of ZL is less than or equal to 496
    one_cluster() # while length<=496 the function one_cluster is run
    L=L+16 # then add 16 to whatever the length L was before
    a=L-16 # position of first float in the WL list which takes in sets of floats created via one_cluster function
    b=L # position of last float in the WL list which takes in sets of floats created via one_cluster function 
    W=(ZL[a:b]) # W is a list which outputs ZL in sets of 16 floats
    wl=WL.append(W) # append W, the sets of 16 floats, to WL    
    
def bad_cluster ():# function that creates a float error
    one_cluster() # run the function one_cluster to create a cluster
    W[4]="stringentry" # change the 5th entry in this particular cluster to "str"
bad_cluster()

for counter, value in enumerate(WL, 1): # for every entry in WL indexed from 1
        now = datetime.now() # current date and time
        timestamp = datetime.timestamp(now) #assign the timestamp to time found above
        if type(v in value)==str:# if the value is a string
            print("err") # print error after the dataset

        else: # otherwise
            print (timestamp, counter, value) # print the counter and the value
            print ("\n") # then skip a line
        
g= open('sensor_data.csv', "a", newline= '') # create/ open a new file called sensor_data.csv
g.write(str(WL)) # Writing the List created to text file
g.close() #close file when done
            
one_cluster()
# Out:
# 1599597037.451071 1 [0.9905851105322298, 0.27734860454741583, 0.25092882972537034, 0.7273719112563944, 0.4706338129467891, 0.01547710922013501, 0.38819049090186375, 0.6089167397733841, 0.5900274474077879, 0.15973165576261117, 0.5631679624324611, 0.2949703219615294, 0.07887748386399096, 0.10366735470111654, 0.3700997167968678, 0.6336956423833364]
#
#
# 1599597037.451071 2 [0.7079618481132508, 0.6155807941138942, 0.7706732859519874, 0.6795178844490977, 0.5353308411435326, 0.5785152218836376, 0.11749137911714602, 0.8403824157112418, 0.2252285388967794, 0.24317574252200247, 0.0011622301079463604, 0.4468069951814283, 0.22304439367212625, 0.6902752990777744, 0.715541611346755, 0.16856926144276574]
#
#
# ...
